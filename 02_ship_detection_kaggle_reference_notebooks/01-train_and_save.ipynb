# %%
#!pip install tensorflow_hub

# %%
import os
import sys
import argparse
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_hub as hub
from pathlib import Path
import pandas as pd
import glob
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.utils import class_weight
import multiprocessing
import numpy as np
import json as json
from tensorflow.python.tools import freeze_graph
from tensorflow.keras.utils import plot_model, to_categorical

# %%
input_height = 224
input_width = 224
input_chan = 3
epochs = 100
learnrate =0.1
batchsize = 100
output_ckpt_path = './build/chkpts/float_model.ckpt'
infer_graph_path = './build/chkpts/inference_graph.pb'
tboard_path = './build/tb_logs'
num_classes = 43

# Set up directories and files
INFER_GRAPH_DIR = os.path.dirname(infer_graph_path)
INFER_GRAPH_FILENAME =os.path.basename(infer_graph_path)

# %%
#import keras
#config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} ) 
#sess = tf.Session(config=config) 
#keras.backend.set_session(sess)

# Silence TensorFlow messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# workaround for TF1.15 bug "Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR"
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)


class cfg:
    weights = {
        "Agriculture":                                               67256 ,
        "Airports": 0,
        "Annual crops associated with permanent crops" : 0,
        "Bare rock": 0,
        "Beaches, dunes, sands":0,
        "Burnt areas":0,
        "Coastal lagoons":0,
        "Construction sites": 0,
        "Continuous urban fabric": 0,
        "Discontinuous urban fabric":0,
        "Estuaries":0,
        "Fruit trees and berry plantations":0,
        "Green urban areas":0,
        "Land principally occupied by agriculture, with significant areas of natural vegetation":0,
        "Mineral extraction sites":0,
        "Inland marshes":0,
        "Agro-forestry areas":					  15790 ,
        "Arable land":						 100394 ,
        "Beaches,dunes,sands":					   1193 ,
        "Broad-leaved forest":					  73407 ,
        "Coastal wetlands":						   1033 ,
        "Complex cultivation patterns":				  53530 ,
        "Coniferous forest":					  86569 ,
        "Dump sites":0,
        "Industrial or commercial units":				   6182 ,
        "Inland waters":						  35349 ,
        "Inland wetlands":						  11620 ,
        "Intertidal flats":0,
        "Marine waters":						  39110 ,
        "Mixed forest":						  91926 ,
        "Moors and heathland":0,
        "Natural grassland":0,
        "Moors,heathlandandsclerophyllousvegetation":		   8434 ,
        "Naturalgrasslandandsparselyvegetatedareas":		   6663 ,
        "Non-irrigated arable land":0,
        "Olive groves":0,
        "Peatbogs":0,
        "Pastures":						  50977 ,
        "Permanent crops":				  15862 ,
        "Port areas":0,
        "Rice fields":0,
        "Road and rail networks and associated land":0,
        "Permanently irrigated land":0,
        "Salt marshes":0,
        "Salines":0,
        "Transitional woodland/shrub":				  77589 ,
        "Sclerophyllous vegetation":0,
        "Sea and ocean":0,
        "Urbanfabric":					  38779,
        "Sport and leisure facilities":0,
        "Sparsely vegetated areas":0,
        "Vineyards":0,
        "Water bodies":0,
        "Water courses":0
}



def get_data(path_images):
    classes_arr = []
    files = glob.glob(str(path_images) + "/*/" + '*.tif')

    for filename in files:
        out = Path(filename)
        parent = out.resolve().parent
        label_file = glob.glob(str(parent) + '/*.json')[0]

        with open(label_file) as json_file:
            data = json.load(json_file)
        name = data['labels']
        classes_arr.append([str(out), name])

    return pd.DataFrame(classes_arr, columns=['files', 'labels'])

# load data paths to dictionaries.
#root_path = "/root/tensorflow_datasets/"
root_path = "/workspace/data/"
dict_train = get_data(root_path+"train/")
dict_test = get_data(root_path+"test/")
dict_val = get_data(root_path+"val/")

mlb = MultiLabelBinarizer()
mlb.fit(dict_train['labels'])
print("Labels:")
for (i, label) in enumerate(mlb.classes_):
    print("{}. {}".format(i, label))


# Create Data Iterators
#Data generator for training data
train_datagen = ImageDataGenerator(rescale=1. / 255)
train_generator = train_datagen.flow_from_dataframe(
    dict_train,
    x_col='files',
    y_col='labels',
    target_size=(input_height,input_width),
    batch_size=batchsize,
    class_mode='categorical',
)
### Now compute class weights from this

import sys
weight_sum = sum([cfg.weights[x] for x in cfg.weights])
print("Total Weight: %s" % weight_sum)
weights = {y:(cfg.weights[x] / weight_sum) for y,x in enumerate(mlb.classes_)}

#Data generator for test data
test_datagen = ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_dataframe(
    dict_test,
    x_col='files',
    y_col='labels',
    target_size=(input_height,input_width),
    batch_size=batchsize,
    class_mode='categorical',
    shuffle=False
)

#Data generator for validation data
validation_datagen = ImageDataGenerator(rescale=1. / 255)
validation_generator = validation_datagen.flow_from_dataframe(
    dict_val,
    x_col='files',
    y_col='labels',
    target_size=(input_height,input_width),
    batch_size=batchsize,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Labels:
# 0. Agro-forestry areas
# 1. Airports
# 2. Annual crops associated with permanent crops
# 3. Bare rock
# 4. Beaches, dunes, sands
# 5. Broad-leaved forest
# 6. Burnt areas
# 7. Coastal lagoons
# 8. Complex cultivation patterns
# 9. Coniferous forest
# 10. Construction sites
# 11. Continuous urban fabric
# 12. Discontinuous urban fabric
# 13. Dump sites
# 14. Estuaries
# 15. Fruit trees and berry plantations
# 16. Green urban areas
# 17. Industrial or commercial units
# 18. Inland marshes
# 19. Intertidal flats
# 20. Land principally occupied by agriculture, with significant areas of natural vegetation
# 21. Mineral extraction sites
# 22. Mixed forest
# 23. Moors and heathland
# 24. Natural grassland
# 25. Non-irrigated arable land
# 26. Olive groves
# 27. Pastures
# 28. Peatbogs
# 29. Permanently irrigated land
# 30. Port areas
# 31. Rice fields
# 32. Road and rail networks and associated land
# 33. Salines
# 34. Salt marshes
# 35. Sclerophyllous vegetation
# 36. Sea and ocean
# 37. Sparsely vegetated areas
# 38. Sport and leisure facilities
# 39. Transitional woodland/shrub
# 40. Vineyards
# 41. Water bodies
# 42. Water courses
# Found 58008 validated image filenames belonging to 43 classes.
# Total Weight: 781663
# Found 62748 validated image filenames belonging to 43 classes.
# Found 41016 validated image filenames belonging to 43 classes.

# %%
# get number of cores
num_cpus = multiprocessing.cpu_count()
print("Number of cores: %s" %num_cpus)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))


# Create a callback for storing the model. This will be used for quantization later
fname = os.path.sep.join([INFER_GRAPH_DIR, "best-model.ckpt"])
checkpoint = tf.keras.callbacks.ModelCheckpoint(fname,
                            monitor="val_loss", mode="min",
                            #monitor="val_acc", mode="max",
                            save_best_only=True, verbose=1)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tboard_path)

def create_model ():
    ##########################################
    ##########################################
    ##########################################

    #hub_layer = hub.KerasLayer("https://tfhub.dev/google/remote_sensing/bigearthnet-resnet50/1", trainable=False, input_shape=(input_height,input_width, input_chan), )
    #newInputs = tf.keras.layers.Input(shape=(input_height,input_width, input_chan))    # let us say this new InputLayer
    #x = hub_layer (newInputs)
    #x = tf.keras.layers.Flatten()(x)
    #newOutputs = tf.keras.layers.Dense(num_classes, activation='sigmoid')(x)
    #model = tf.keras.Model(newInputs, newOutputs)

    ##########################################
    ##########################################
    ##########################################

    #hub_layer = hub.KerasLayer("https://tfhub.dev/google/remote_sensing/bigearthnet-resnet50/1", trainable=False, input_shape=(input_height,input_width, input_chan))
    #model = tf.keras.Sequential()
    #model.add(hub_layer)
    #model.add(tf.keras.layers.Dense(num_classes, activation='sigmoid'))

    ##########################################
    ##########################################
    ##########################################

    #model = tf.keras.Sequential([
    #    hub.KerasLayer("https://tfhub.dev/google/imagenet/mobilenet_v1_100_224/feature_vector/4",
    #                   trainable=False),
    #    tf.keras.layers.Dense(num_classes, activation='softmax')
    #])
    #model.build([None, 12, 12, 3])  # Batch input shape.

    ##########################################
    ##########################################
    ##########################################

    #model = tf.keras.Sequential()
    #model.add(tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation="relu",input_shape=(12,12,3)))
    #model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    #model.add(tf.keras.layers.Flatten())
    #model.add(tf.keras.layers.Dense(100, activation='sigmoid'))
    #model.add(tf.keras.layers.Dense(43, activation='softmax'))

    ##########################################
    ##########################################
    ##########################################

    #resnet = tf.keras.applications.ResNet50(
    #    include_top=False,
    #    input_tensor=None,
    #    input_shape=(input_height, input_width, input_chan),
    #    pooling=None,
    #    #classes=num_classes
    #)
    #newInputs = tf.keras.layers.Input(shape=(input_height,input_width, input_chan))
    #
    #x = resnet (newInputs)
    #x = tf.keras.layers.Flatten()(x)
    #newOutputs = tf.keras.layers.Dense(num_classes, activation='sigmoid')(x)
    #
    #model = tf.keras.Model(newInputs, newOutputs)
    #
    #return model

    ##########################################
    ##########################################
    ##########################################
    
    resnet = tf.keras.applications.ResNet50V2 (
        include_top=False,
        input_tensor=None,
        input_shape=(input_height, input_width, input_chan),
        pooling=None,
        #classes=num_classes
    )
    newInputs = tf.keras.layers.Input(shape=(input_height,input_width, input_chan))

    x = resnet (newInputs)
    x = tf.keras.layers.Flatten()(x)
    newOutputs = tf.keras.layers.Dense(num_classes, activation='sigmoid')(x)

    model = tf.keras.Model(newInputs, newOutputs)
    
    return model

    ##########################################
    ##########################################
    ##########################################

#strategy = tf.distribute.MirroredStrategy()
#print("Number of devices: {}".format(strategy.num_replicas_in_sync))
#with strategy.scope():
model = create_model()
model.compile(
        loss='binary_crossentropy',
        optimizer=tf.keras.optimizers.SGD(learning_rate=learnrate, momentum=0.9),
        metrics=[tf.keras.metrics.Precision(), tf.keras.metrics.Recall()] 
)



# Training phase with training data
print("\n----------------------------",flush=True)
print(" TRAINING STARTED...",flush=True)
print("----------------------------",flush=True)

history = model.fit(
        train_generator,
        epochs=epochs,
        validation_steps=validation_generator.samples/validation_generator.batch_size,
        steps_per_epoch=train_generator.samples/train_generator.batch_size,
        validation_data=validation_generator,
        callbacks=[checkpoint, tensorboard_callback],
        workers=num_cpus,
        #class_weight=weights,
        verbose=1
)

# Training phase with training data
print("\n----------------------------",flush=True)
print(" TRAINING DONE...",flush=True)
print("----------------------------",flush=True)


print(' Run `tensorboard --logdir=%s --port 6006 --host localhost` to see the results.' % tboard_path,flush=True)
# Out:
# Number of cores: 32
# Num GPUs Available:  2
#
# ----------------------------
#  TRAINING STARTED...
# ----------------------------
# Epoch 1/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1756 - precision: 0.5693 - recall: 0.1268
# Epoch 00001: val_loss improved from inf to 0.16554, saving model to ./build/chkpts/best-model.ckpt
# 581/580 [==============================] - 501s 863ms/step - loss: 0.1756 - precision: 0.5693 - recall: 0.1268 - val_loss: 0.1655 - val_precision: 0.6333 - val_recall: 0.1117
# Epoch 2/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1512 - precision: 0.7290 - recall: 0.1706
# Epoch 00002: val_loss did not improve from 0.16554
# 581/580 [==============================] - 388s 668ms/step - loss: 0.1512 - precision: 0.7290 - recall: 0.1706 - val_loss: 0.2145 - val_precision: 0.3289 - val_recall: 0.1137
# Epoch 3/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1426 - precision: 0.7744 - recall: 0.2184
# Epoch 00003: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.1426 - precision: 0.7744 - recall: 0.2184 - val_loss: 0.1736 - val_precision: 0.5876 - val_recall: 0.1483
# Epoch 4/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1349 - precision: 0.8024 - recall: 0.2682
# Epoch 00004: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.1349 - precision: 0.8024 - recall: 0.2682 - val_loss: 0.4652 - val_precision: 0.3210 - val_recall: 0.1389
# Epoch 5/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1266 - precision: 0.8341 - recall: 0.3160
# Epoch 00005: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.1266 - precision: 0.8341 - recall: 0.3160 - val_loss: 0.1962 - val_precision: 0.5097 - val_recall: 0.1561
# Epoch 6/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1199 - precision: 0.8606 - recall: 0.3530
# Epoch 00006: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.1199 - precision: 0.8606 - recall: 0.3530 - val_loss: 0.4849 - val_precision: 0.3176 - val_recall: 0.1331
# Epoch 7/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1122 - precision: 0.8899 - recall: 0.3907
# Epoch 00007: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.1122 - precision: 0.8899 - recall: 0.3907 - val_loss: 0.5337 - val_precision: 0.3226 - val_recall: 0.1455
# Epoch 8/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1073 - precision: 0.9019 - recall: 0.4177
# Epoch 00008: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.1073 - precision: 0.9019 - recall: 0.4177 - val_loss: 0.2392 - val_precision: 0.4296 - val_recall: 0.2371
# Epoch 9/100
# 581/580 [==============================] - ETA: 0s - loss: 0.1008 - precision: 0.9266 - recall: 0.4472
# Epoch 00009: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.1008 - precision: 0.9266 - recall: 0.4472 - val_loss: 0.4719 - val_precision: 0.3330 - val_recall: 0.1557
# Epoch 10/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0986 - precision: 0.9273 - recall: 0.4605
# Epoch 00010: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0986 - precision: 0.9273 - recall: 0.4605 - val_loss: 0.5237 - val_precision: 0.3348 - val_recall: 0.1576
# Epoch 11/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0928 - precision: 0.9532 - recall: 0.4827
# Epoch 00011: val_loss did not improve from 0.16554
# 581/580 [==============================] - 388s 668ms/step - loss: 0.0928 - precision: 0.9532 - recall: 0.4827 - val_loss: 0.6396 - val_precision: 0.3197 - val_recall: 0.1486
# Epoch 12/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0931 - precision: 0.9479 - recall: 0.4848
# Epoch 00012: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0931 - precision: 0.9479 - recall: 0.4848 - val_loss: 0.3139 - val_precision: 0.4787 - val_recall: 0.1744
# Epoch 13/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0899 - precision: 0.9611 - recall: 0.4966
# Epoch 00013: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0899 - precision: 0.9611 - recall: 0.4966 - val_loss: 0.3053 - val_precision: 0.4249 - val_recall: 0.2396
# Epoch 14/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0865 - precision: 0.9695 - recall: 0.5103
# Epoch 00014: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0865 - precision: 0.9695 - recall: 0.5103 - val_loss: 0.6775 - val_precision: 0.3312 - val_recall: 0.1408
# Epoch 15/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0918 - precision: 0.9483 - recall: 0.4909
# Epoch 00015: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0918 - precision: 0.9483 - recall: 0.4909 - val_loss: 0.5764 - val_precision: 0.3312 - val_recall: 0.1475
# Epoch 16/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0854 - precision: 0.9757 - recall: 0.5138
# Epoch 00016: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0854 - precision: 0.9757 - recall: 0.5138 - val_loss: 0.3324 - val_precision: 0.4589 - val_recall: 0.2495
# Epoch 17/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0840 - precision: 0.9783 - recall: 0.5213
# Epoch 00017: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0840 - precision: 0.9783 - recall: 0.5213 - val_loss: 0.3300 - val_precision: 0.4530 - val_recall: 0.2517
# Epoch 18/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0823 - precision: 0.9853 - recall: 0.5258
# Epoch 00018: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0823 - precision: 0.9853 - recall: 0.5258 - val_loss: 0.3481 - val_precision: 0.4675 - val_recall: 0.1904
# Epoch 19/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0817 - precision: 0.9875 - recall: 0.5287
# Epoch 00019: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0817 - precision: 0.9875 - recall: 0.5287 - val_loss: 0.9310 - val_precision: 0.3336 - val_recall: 0.1425
# Epoch 20/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0810 - precision: 0.9862 - recall: 0.5326
# Epoch 00020: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0810 - precision: 0.9862 - recall: 0.5326 - val_loss: 0.3743 - val_precision: 0.4567 - val_recall: 0.2617
# Epoch 21/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0831 - precision: 0.9811 - recall: 0.5261
# Epoch 00021: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0831 - precision: 0.9811 - recall: 0.5261 - val_loss: 0.7673 - val_precision: 0.3281 - val_recall: 0.1399
# Epoch 22/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0809 - precision: 0.9878 - recall: 0.5326
# Epoch 00022: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0809 - precision: 0.9878 - recall: 0.5326 - val_loss: 0.8856 - val_precision: 0.3361 - val_recall: 0.1418
# Epoch 23/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0820 - precision: 0.9838 - recall: 0.5298
# Epoch 00023: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0820 - precision: 0.9838 - recall: 0.5298 - val_loss: 0.3653 - val_precision: 0.4660 - val_recall: 0.1901
# Epoch 24/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0808 - precision: 0.9865 - recall: 0.5339
# Epoch 00024: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0808 - precision: 0.9865 - recall: 0.5339 - val_loss: 0.6699 - val_precision: 0.3445 - val_recall: 0.1633
# Epoch 25/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0807 - precision: 0.9876 - recall: 0.5340
# Epoch 00025: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0807 - precision: 0.9876 - recall: 0.5340 - val_loss: 0.3885 - val_precision: 0.4764 - val_recall: 0.1858
# Epoch 26/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0794 - precision: 0.9916 - recall: 0.5387
# Epoch 00026: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0794 - precision: 0.9916 - recall: 0.5387 - val_loss: 1.0303 - val_precision: 0.3307 - val_recall: 0.1334
# Epoch 27/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0799 - precision: 0.9897 - recall: 0.5374
# Epoch 00027: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0799 - precision: 0.9897 - recall: 0.5374 - val_loss: 0.3791 - val_precision: 0.4754 - val_recall: 0.1935
# Epoch 28/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0791 - precision: 0.9931 - recall: 0.5392
# Epoch 00028: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0791 - precision: 0.9931 - recall: 0.5392 - val_loss: 1.1291 - val_precision: 0.3290 - val_recall: 0.1344
# Epoch 29/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0787 - precision: 0.9949 - recall: 0.5405
# Epoch 00029: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0787 - precision: 0.9949 - recall: 0.5405 - val_loss: 0.4193 - val_precision: 0.4751 - val_recall: 0.1917
# Epoch 30/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0784 - precision: 0.9934 - recall: 0.5422
# Epoch 00030: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0784 - precision: 0.9934 - recall: 0.5422 - val_loss: 0.4515 - val_precision: 0.4882 - val_recall: 0.1853
# Epoch 31/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0782 - precision: 0.9951 - recall: 0.5428
# Epoch 00031: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0782 - precision: 0.9951 - recall: 0.5428 - val_loss: 0.4198 - val_precision: 0.4655 - val_recall: 0.1874
# Epoch 32/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0779 - precision: 0.9967 - recall: 0.5430
# Epoch 00032: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0779 - precision: 0.9967 - recall: 0.5430 - val_loss: 0.4293 - val_precision: 0.4701 - val_recall: 0.1952
# Epoch 33/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0800 - precision: 0.9888 - recall: 0.5378
# Epoch 00033: val_loss did not improve from 0.16554
# 581/580 [==============================] - 388s 668ms/step - loss: 0.0800 - precision: 0.9888 - recall: 0.5378 - val_loss: 0.4077 - val_precision: 0.4612 - val_recall: 0.1932
# Epoch 34/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0785 - precision: 0.9943 - recall: 0.5417
# Epoch 00034: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0785 - precision: 0.9943 - recall: 0.5417 - val_loss: 1.1434 - val_precision: 0.3317 - val_recall: 0.1372
# Epoch 35/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0780 - precision: 0.9960 - recall: 0.5431
# Epoch 00035: val_loss did not improve from 0.16554
# 581/580 [==============================] - 388s 668ms/step - loss: 0.0780 - precision: 0.9960 - recall: 0.5431 - val_loss: 1.3958 - val_precision: 0.3282 - val_recall: 0.1334
# Epoch 36/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0779 - precision: 0.9964 - recall: 0.5436
# Epoch 00036: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0779 - precision: 0.9964 - recall: 0.5436 - val_loss: 1.0844 - val_precision: 0.3438 - val_recall: 0.1442
# Epoch 37/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0776 - precision: 0.9974 - recall: 0.5439
# Epoch 00037: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0776 - precision: 0.9974 - recall: 0.5439 - val_loss: 0.4464 - val_precision: 0.3519 - val_recall: 0.1920
# Epoch 38/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0776 - precision: 0.9974 - recall: 0.5443
# Epoch 00038: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0776 - precision: 0.9974 - recall: 0.5443 - val_loss: 0.4675 - val_precision: 0.3545 - val_recall: 0.1895
# Epoch 39/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0775 - precision: 0.9968 - recall: 0.5448
# Epoch 00039: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0775 - precision: 0.9968 - recall: 0.5448 - val_loss: 0.6968 - val_precision: 0.3607 - val_recall: 0.1706
# Epoch 40/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0774 - precision: 0.9978 - recall: 0.5447
# Epoch 00040: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0774 - precision: 0.9978 - recall: 0.5447 - val_loss: 1.4177 - val_precision: 0.3231 - val_recall: 0.1250
# Epoch 41/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0791 - precision: 0.9901 - recall: 0.5416
# Epoch 00041: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 670ms/step - loss: 0.0791 - precision: 0.9901 - recall: 0.5416 - val_loss: 0.4325 - val_precision: 0.4712 - val_recall: 0.1969
# Epoch 42/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0777 - precision: 0.9966 - recall: 0.5440
# Epoch 00042: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0777 - precision: 0.9966 - recall: 0.5440 - val_loss: 1.3017 - val_precision: 0.3290 - val_recall: 0.1377
# Epoch 43/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0778 - precision: 0.9965 - recall: 0.5441
# Epoch 00043: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0778 - precision: 0.9965 - recall: 0.5441 - val_loss: 1.1092 - val_precision: 0.3522 - val_recall: 0.1543
# Epoch 44/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0777 - precision: 0.9965 - recall: 0.5443
# Epoch 00044: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0777 - precision: 0.9965 - recall: 0.5443 - val_loss: 1.2185 - val_precision: 0.3059 - val_recall: 0.1394
# Epoch 45/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0787 - precision: 0.9931 - recall: 0.5412
# Epoch 00045: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0787 - precision: 0.9931 - recall: 0.5412 - val_loss: 1.5932 - val_precision: 0.3253 - val_recall: 0.1274
# Epoch 46/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0778 - precision: 0.9962 - recall: 0.5441
# Epoch 00046: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0778 - precision: 0.9962 - recall: 0.5441 - val_loss: 0.4331 - val_precision: 0.4725 - val_recall: 0.1869
# Epoch 47/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0774 - precision: 0.9976 - recall: 0.5449
# Epoch 00047: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0774 - precision: 0.9976 - recall: 0.5449 - val_loss: 0.6280 - val_precision: 0.3493 - val_recall: 0.1847
# Epoch 48/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0774 - precision: 0.9976 - recall: 0.5453
# Epoch 00048: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0774 - precision: 0.9976 - recall: 0.5453 - val_loss: 1.3510 - val_precision: 0.3334 - val_recall: 0.1327
# Epoch 49/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0773 - precision: 0.9978 - recall: 0.5455
# Epoch 00049: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0773 - precision: 0.9978 - recall: 0.5455 - val_loss: 1.2432 - val_precision: 0.3292 - val_recall: 0.1308
# Epoch 50/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0773 - precision: 0.9981 - recall: 0.5456
# Epoch 00050: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 669ms/step - loss: 0.0773 - precision: 0.9981 - recall: 0.5456 - val_loss: 0.4635 - val_precision: 0.4726 - val_recall: 0.1911
# Epoch 51/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9978 - recall: 0.5456
# Epoch 00051: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0772 - precision: 0.9978 - recall: 0.5456 - val_loss: 1.5352 - val_precision: 0.3235 - val_recall: 0.1297
# Epoch 52/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0771 - precision: 0.9961 - recall: 0.5468
# Epoch 00052: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0771 - precision: 0.9961 - recall: 0.5468 - val_loss: 0.4866 - val_precision: 0.4729 - val_recall: 0.1903
# Epoch 53/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0771 - precision: 0.9973 - recall: 0.5460
# Epoch 00053: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0771 - precision: 0.9973 - recall: 0.5460 - val_loss: 0.4646 - val_precision: 0.4668 - val_recall: 0.1931
# Epoch 54/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0771 - precision: 0.9979 - recall: 0.5459
# Epoch 00054: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0771 - precision: 0.9979 - recall: 0.5459 - val_loss: 1.3582 - val_precision: 0.3362 - val_recall: 0.1367
# Epoch 55/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9983 - recall: 0.5461
# Epoch 00055: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0770 - precision: 0.9983 - recall: 0.5461 - val_loss: 0.4982 - val_precision: 0.4799 - val_recall: 0.1882
# Epoch 56/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9987 - recall: 0.5462
# Epoch 00056: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0770 - precision: 0.9987 - recall: 0.5462 - val_loss: 1.1363 - val_precision: 0.3590 - val_recall: 0.1570
# Epoch 57/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0775 - precision: 0.9967 - recall: 0.5453
# Epoch 00057: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 672ms/step - loss: 0.0775 - precision: 0.9967 - recall: 0.5453 - val_loss: 0.4477 - val_precision: 0.3517 - val_recall: 0.1935
# Epoch 58/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0778 - precision: 0.9959 - recall: 0.5445
# Epoch 00058: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0778 - precision: 0.9959 - recall: 0.5445 - val_loss: 0.4464 - val_precision: 0.3497 - val_recall: 0.1925
# Epoch 59/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0773 - precision: 0.9966 - recall: 0.5460
# Epoch 00059: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0773 - precision: 0.9966 - recall: 0.5460 - val_loss: 0.4666 - val_precision: 0.4714 - val_recall: 0.1983
# Epoch 60/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0777 - precision: 0.9960 - recall: 0.5448
# Epoch 00060: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0777 - precision: 0.9960 - recall: 0.5448 - val_loss: 1.5504 - val_precision: 0.2057 - val_recall: 0.1164
# Epoch 61/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0788 - precision: 0.9912 - recall: 0.5417
# Epoch 00061: val_loss did not improve from 0.16554
# 581/580 [==============================] - 388s 669ms/step - loss: 0.0788 - precision: 0.9912 - recall: 0.5417 - val_loss: 0.4475 - val_precision: 0.4630 - val_recall: 0.1929
# Epoch 62/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0775 - precision: 0.9967 - recall: 0.5450
# Epoch 00062: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 674ms/step - loss: 0.0775 - precision: 0.9967 - recall: 0.5450 - val_loss: 1.4048 - val_precision: 0.2486 - val_recall: 0.1440
# Epoch 63/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9978 - recall: 0.5461
# Epoch 00063: val_loss did not improve from 0.16554
# 581/580 [==============================] - 388s 668ms/step - loss: 0.0772 - precision: 0.9978 - recall: 0.5461 - val_loss: 1.1984 - val_precision: 0.3386 - val_recall: 0.1436
# Epoch 64/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9982 - recall: 0.5460
# Epoch 00064: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0772 - precision: 0.9982 - recall: 0.5460 - val_loss: 0.4667 - val_precision: 0.4723 - val_recall: 0.1864
# Epoch 65/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9977 - recall: 0.5460
# Epoch 00065: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0772 - precision: 0.9977 - recall: 0.5460 - val_loss: 0.4862 - val_precision: 0.4758 - val_recall: 0.1937
# Epoch 66/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0794 - precision: 0.9895 - recall: 0.5410
# Epoch 00066: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0794 - precision: 0.9895 - recall: 0.5410 - val_loss: 0.4392 - val_precision: 0.4617 - val_recall: 0.1811
# Epoch 67/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0780 - precision: 0.9936 - recall: 0.5444
# Epoch 00067: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0780 - precision: 0.9936 - recall: 0.5444 - val_loss: 0.5831 - val_precision: 0.3472 - val_recall: 0.1786
# Epoch 68/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0773 - precision: 0.9975 - recall: 0.5457
# Epoch 00068: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0773 - precision: 0.9975 - recall: 0.5457 - val_loss: 0.5155 - val_precision: 0.3494 - val_recall: 0.1829
# Epoch 69/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0771 - precision: 0.9981 - recall: 0.5464
# Epoch 00069: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0771 - precision: 0.9981 - recall: 0.5464 - val_loss: 0.4525 - val_precision: 0.4790 - val_recall: 0.1799
# Epoch 70/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9980 - recall: 0.5461
# Epoch 00070: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0772 - precision: 0.9980 - recall: 0.5461 - val_loss: 0.4437 - val_precision: 0.4556 - val_recall: 0.1954
# Epoch 71/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0777 - precision: 0.9945 - recall: 0.5452
# Epoch 00071: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0777 - precision: 0.9945 - recall: 0.5452 - val_loss: 1.5108 - val_precision: 0.3238 - val_recall: 0.1336
# Epoch 72/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0771 - precision: 0.9979 - recall: 0.5462
# Epoch 00072: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0771 - precision: 0.9979 - recall: 0.5462 - val_loss: 0.5384 - val_precision: 0.3519 - val_recall: 0.1907
# Epoch 73/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9976 - recall: 0.5460
# Epoch 00073: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0772 - precision: 0.9976 - recall: 0.5460 - val_loss: 0.6467 - val_precision: 0.3481 - val_recall: 0.1828
# Epoch 74/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9983 - recall: 0.5465
# Epoch 00074: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0770 - precision: 0.9983 - recall: 0.5465 - val_loss: 0.7102 - val_precision: 0.3515 - val_recall: 0.1838
# Epoch 75/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9983 - recall: 0.5465
# Epoch 00075: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0770 - precision: 0.9983 - recall: 0.5465 - val_loss: 1.4420 - val_precision: 0.3373 - val_recall: 0.1412
# Epoch 76/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0769 - precision: 0.9985 - recall: 0.5466
# Epoch 00076: val_loss did not improve from 0.16554
# 581/580 [==============================] - 392s 674ms/step - loss: 0.0769 - precision: 0.9985 - recall: 0.5466 - val_loss: 0.5146 - val_precision: 0.3520 - val_recall: 0.1895
# Epoch 77/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9984 - recall: 0.5463
# Epoch 00077: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0770 - precision: 0.9984 - recall: 0.5463 - val_loss: 1.1654 - val_precision: 0.3287 - val_recall: 0.1312
# Epoch 78/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0769 - precision: 0.9988 - recall: 0.5468
# Epoch 00078: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0769 - precision: 0.9988 - recall: 0.5468 - val_loss: 1.0769 - val_precision: 0.3469 - val_recall: 0.1504
# Epoch 79/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0768 - precision: 0.9990 - recall: 0.5469
# Epoch 00079: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 673ms/step - loss: 0.0768 - precision: 0.9990 - recall: 0.5469 - val_loss: 0.5198 - val_precision: 0.4761 - val_recall: 0.1855
# Epoch 80/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0768 - precision: 0.9990 - recall: 0.5471
# Epoch 00080: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0768 - precision: 0.9990 - recall: 0.5471 - val_loss: 0.5166 - val_precision: 0.4759 - val_recall: 0.1838
# Epoch 81/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0879 - precision: 0.9578 - recall: 0.5128
# Epoch 00081: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0879 - precision: 0.9578 - recall: 0.5128 - val_loss: 0.3263 - val_precision: 0.4634 - val_recall: 0.1544
# Epoch 82/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0897 - precision: 0.9508 - recall: 0.5042
# Epoch 00082: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0897 - precision: 0.9508 - recall: 0.5042 - val_loss: 0.3305 - val_precision: 0.4627 - val_recall: 0.1912
# Epoch 83/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0815 - precision: 0.9822 - recall: 0.5322
# Epoch 00083: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0815 - precision: 0.9822 - recall: 0.5322 - val_loss: 0.3893 - val_precision: 0.4700 - val_recall: 0.1811
# Epoch 84/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0800 - precision: 0.9883 - recall: 0.5370
# Epoch 00084: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 673ms/step - loss: 0.0800 - precision: 0.9883 - recall: 0.5370 - val_loss: 0.5116 - val_precision: 0.3487 - val_recall: 0.1752
# Epoch 85/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0787 - precision: 0.9911 - recall: 0.5424
# Epoch 00085: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0787 - precision: 0.9911 - recall: 0.5424 - val_loss: 0.4082 - val_precision: 0.4232 - val_recall: 0.2377
# Epoch 86/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0780 - precision: 0.9951 - recall: 0.5437
# Epoch 00086: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 672ms/step - loss: 0.0780 - precision: 0.9951 - recall: 0.5437 - val_loss: 0.4246 - val_precision: 0.4657 - val_recall: 0.1818
# Epoch 87/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0775 - precision: 0.9969 - recall: 0.5451
# Epoch 00087: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0775 - precision: 0.9969 - recall: 0.5451 - val_loss: 0.4387 - val_precision: 0.4645 - val_recall: 0.1924
# Epoch 88/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0783 - precision: 0.9941 - recall: 0.5427
# Epoch 00088: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 672ms/step - loss: 0.0783 - precision: 0.9941 - recall: 0.5427 - val_loss: 1.1706 - val_precision: 0.3278 - val_recall: 0.1317
# Epoch 89/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0786 - precision: 0.9932 - recall: 0.5421
# Epoch 00089: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 674ms/step - loss: 0.0786 - precision: 0.9932 - recall: 0.5421 - val_loss: 0.4021 - val_precision: 0.4261 - val_recall: 0.2422
# Epoch 90/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0781 - precision: 0.9949 - recall: 0.5434
# Epoch 00090: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0781 - precision: 0.9949 - recall: 0.5434 - val_loss: 0.4327 - val_precision: 0.4536 - val_recall: 0.1887
# Epoch 91/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0777 - precision: 0.9949 - recall: 0.5449
# Epoch 00091: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0777 - precision: 0.9949 - recall: 0.5449 - val_loss: 0.4946 - val_precision: 0.4455 - val_recall: 0.2558
# Epoch 92/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0776 - precision: 0.9965 - recall: 0.5445
# Epoch 00092: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0776 - precision: 0.9965 - recall: 0.5445 - val_loss: 0.4635 - val_precision: 0.4542 - val_recall: 0.2540
# Epoch 93/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0771 - precision: 0.9981 - recall: 0.5460
# Epoch 00093: val_loss did not improve from 0.16554
# 581/580 [==============================] - 392s 674ms/step - loss: 0.0771 - precision: 0.9981 - recall: 0.5460 - val_loss: 1.3042 - val_precision: 0.3161 - val_recall: 0.1279
# Epoch 94/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9978 - recall: 0.5457
# Epoch 00094: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0772 - precision: 0.9978 - recall: 0.5457 - val_loss: 1.2259 - val_precision: 0.3271 - val_recall: 0.1363
# Epoch 95/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0772 - precision: 0.9976 - recall: 0.5460
# Epoch 00095: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0772 - precision: 0.9976 - recall: 0.5460 - val_loss: 0.4815 - val_precision: 0.4615 - val_recall: 0.1894
# Epoch 96/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9981 - recall: 0.5463
# Epoch 00096: val_loss did not improve from 0.16554
# 581/580 [==============================] - 391s 673ms/step - loss: 0.0770 - precision: 0.9981 - recall: 0.5463 - val_loss: 1.3512 - val_precision: 0.3222 - val_recall: 0.1302
# Epoch 97/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0770 - precision: 0.9985 - recall: 0.5465
# Epoch 00097: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0770 - precision: 0.9985 - recall: 0.5465 - val_loss: 1.2505 - val_precision: 0.3283 - val_recall: 0.1308
# Epoch 98/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0769 - precision: 0.9988 - recall: 0.5468
# Epoch 00098: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0769 - precision: 0.9988 - recall: 0.5468 - val_loss: 1.2295 - val_precision: 0.3357 - val_recall: 0.1413
# Epoch 99/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0769 - precision: 0.9986 - recall: 0.5468
# Epoch 00099: val_loss did not improve from 0.16554
# 581/580 [==============================] - 389s 670ms/step - loss: 0.0769 - precision: 0.9986 - recall: 0.5468 - val_loss: 0.4824 - val_precision: 0.4537 - val_recall: 0.2568
# Epoch 100/100
# 581/580 [==============================] - ETA: 0s - loss: 0.0769 - precision: 0.9985 - recall: 0.5468
# Epoch 00100: val_loss did not improve from 0.16554
# 581/580 [==============================] - 390s 671ms/step - loss: 0.0769 - precision: 0.9985 - recall: 0.5468 - val_loss: 0.5392 - val_precision: 0.4790 - val_recall: 0.1808
#
# ----------------------------
#  TRAINING DONE...
# ----------------------------
#  Run `tensorboard --logdir=./build/tb_logs --port 6006 --host localhost` to see the results.

# %%
#tf.keras.backend.set_learning_phase(0)

# fetch the tensorflow session using the Keras backend
#tf_session = tf.keras.backend.get_session()
# write out tensorflow checkpoint & meta graph
#saver = tf.compat.v1.train.Saver()
#save_path = saver.save(tf_session, output_ckpt_path)
#print (' Checkpoint created :', output_ckpt_path)

# set up tensorflow saver object
#saver = tf.compat.v1.train.Saver()
#sess = tf.compat.v1.keras.backend.get_session()
#saver.save(sess, output_ckpt_path)
#model.save(filepath= output_ckpt_path)
#tf.keras.models.save_model(model, filepath=INFER_GRAPH_DIR, save_format='tf')
#with tf.compat.v1.Graph().as_default():
    # define placeholders for the input data
    #x_1 = tf.compat.v1.placeholder(tf.float32, shape=[None,input_height,input_width,input_chan], name='input_1')

    # call the CNN function with is_training=False
    #customcnn = tf.keras.Model(inputs=model.inputs,outputs=model.get_layer(name="dense").output)
    #logits_1 = customcnn(cnn_in=x_1, is_training=False)

#    tf.io.write_graph(tf.compat.v1.get_default_graph().as_graph_def(), INFER_GRAPH_DIR, INFER_GRAPH_FILENAME, as_text=False)
#    print(' Saved binary inference graph to %s' % infer_graph_path)

#sess = tf.compat.v1.keras.backend.get_session()
#tf.compat.v1.train.Saver().save(sess=sess, save_path=INFER_GRAPH_DIR)
#tf.compat.v1.train.write_graph(graph_or_graph_def=sess.graph_def, logdir=INFER_GRAPH_DIR, name=infer_graph_path, as_text=False)
# Method 1
#freeze_graph.freeze_graph(input_graph=pbtxt_filepath, input_saver='', input_binary=False, input_checkpoint=ckpt_filepath, output_node_names='cnn/output', restore_op_name='save/restore_all', filename_tensor_name='save/Const:0', output_graph=pb_filepath, clear_devices=True, initializer_nodes='')

'''
from sklearn import metrics 
predictions = model.predict(test_generator, verbose=1)
ground_truth = test_generator.classes

y_true = MultiLabelBinarizer().fit_transform(ground_truth)
y_pred = np.rint(predictions)
y_score = predictions


f = metrics.f1_score(y_true, y_pred, average='samples')
p = metrics.precision_score(y_true, y_pred, average='samples')
r = metrics.recall_score(y_true, y_pred, average='samples')
AP = metrics.average_precision_score(y_true, y_score)
lrap = metrics.label_ranking_average_precision_score(y_true, y_score)
ji = metrics.jaccard_score(y_true, y_pred, average="samples")
#mAP = mAP(y_true, y_score)
hl = metrics.hamming_loss(y_true, y_pred)
rl = metrics.label_ranking_loss(y_true, y_score)
cov = metrics.coverage_error(y_true, y_score)

print("------------------------------")
print("F1: ", f)
print("presision: ",p)
print("Recall: ", r)
print("AP: ", AP) # edit to mAP
print("lrap: ", lrap)
print("Jaccard Index: ", ji)
#print("mAP", mAP)
print("Hamming Loss: ", hl)
print("Ranking Loss: ", rl)
print("Coverage Error: ", cov)
'''
'''
# Check the input and output name
print ("\n TF input node name:")
print(model.inputs)
print ("\n TF output node name:")
print(model.outputs)

fname = os.path.sep.join([INFER_GRAPH_DIR, "final-model.ckpt"])
tf.keras.experimental.export_saved_model(model, fname)

freeze_graph.freeze_graph(None,
                      None,
                      None,
                      None,
                      model.outputs[0].op.name,
                      None,
                      None,
                      os.path.join(INFER_GRAPH_DIR, "frozen_model.pb"),
                      False,
                      "",
                      input_saved_model_dir='build/chkpts/final-model.ckpt/')
'''
# Out:
# '\n# Check the input and output name\nprint ("\n TF input node name:")\nprint(model.inputs)\nprint ("\n TF output node name:")\nprint(model.outputs)\n\nfname = os.path.sep.join([INFER_GRAPH_DIR, "final-model.ckpt"])\ntf.keras.experimental.export_saved_model(model, fname)\n\nfreeze_graph.freeze_graph(None,\n                      None,\n                      None,\n                      None,\n                      model.outputs[0].op.name,\n                      None,\n                      None,\n                      os.path.join(INFER_GRAPH_DIR, "frozen_model.pb"),\n                      False,\n                      "",\n                      input_saved_model_dir=\'build/chkpts/final-model.ckpt/\')\n'

# %%
# save post-training checkpoint, this saves all the parameters of the trained network
print("\n----------------------------",flush=True)
print(" SAVING CHECKPOINT & GRAPH...",flush=True)
print("----------------------------",flush=True)

#model.build(input_shape=(None, 12,12,3))

#from keras.utils.vis_utils import plot_model
#print the CNN structure
from tensorflow.keras.utils import plot_model, to_categorical
model.summary()
plot_model(model , show_shapes=True, show_layer_names=True, expand_nested=True)

print (model.inputs)
print (model.outputs)
# Out:
# ----------------------------
#  SAVING CHECKPOINT & GRAPH...
# ----------------------------
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 7, 7, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 43)                4315179
# =================================================================
# Total params: 27,879,979
# Trainable params: 27,834,539
# Non-trainable params: 45,440
# _________________________________________________________________
# [<tf.Tensor 'input_2:0' shape=(None, 224, 224, 3) dtype=float32>]
# [<tf.Tensor 'dense/Sigmoid:0' shape=(None, 43) dtype=float32>]

# %%
print(model.layers[0].name)
print(model.layers[-1].name)
print(model.input.name)
print(model.output.name)
# Out:
# input_2
# dense
# input_2:0
# dense/Sigmoid:0

# %%
tf.keras.backend.set_learning_phase(0)
fname = os.path.sep.join([INFER_GRAPH_DIR, "final_model.ckpt"]) 
#tf.compat.experimental.export_saved_model(model, fname) # tf 1
tf.compat.v1.keras.experimental.export_saved_model(model, fname) # tf 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-15e7bd17219e> in <module>
# ----> 1 tf.keras.backend.set_learning_phase(0)
#       2 fname = os.path.sep.join([INFER_GRAPH_DIR, "final_model.ckpt"])
#       3 #tf.compat.experimental.export_saved_model(model, fname) # tf 1
#       4 tf.compat.v1.keras.experimental.export_saved_model(model, fname) # tf 2
#
# NameError: name 'tf' is not defined
